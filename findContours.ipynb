# %%
#This code is written in python 2.7 and OpenCV 3.1.0


# %matplotlib inline
# détection de contours avec OpenCV
import cv2
test_img = "../roof_images/914296300.jpg"
im = cv2.imread(test_img)
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

img = cv2.drawContours(im, contours, -1, (0,255,0), 3)

import matplotlib.pyplot as plt
plt.imshow(img)

# %%
for contour in contours:
    print contour.shape
# Out:
# (1L, 1L, 2L)
# (71L, 1L, 2L)
# (4L, 1L, 2L)
# (6L, 1L, 2L)
# (4L, 1L, 2L)
# (6L, 1L, 2L)
# (6L, 1L, 2L)
# (7L, 1L, 2L)
# (6L, 1L, 2L)
# (4L, 1L, 2L)
# (4L, 1L, 2L)
# (11L, 1L, 2L)
# (12L, 1L, 2L)
# (2L, 1L, 2L)
# (5L, 1L, 2L)
# (6L, 1L, 2L)
# (3L, 1L, 2L)
# (4L, 1L, 2L)
# (174L, 1L, 2L)
# (4L, 1L, 2L)
# (6L, 1L, 2L)
# (7L, 1L, 2L)
# (113L, 1L, 2L)
# (9L, 1L, 2L)
# (7L, 1L, 2L)
# (1L, 1L, 2L)

# %%
#look for the largest contour

img_input = cv2.imread(test_img)
areaArray = []
count = 1
for i, c in enumerate(contours):
    area = cv2.contourArea(c)
    areaArray.append(area)
    areaLargest = np.argmax(areaArray)
    areaLargestMax = max(areaArray)
    areaLargestCnt = contours[areaLargest]
    
for i, c in enumerate(contours):
    area = cv2.contourArea(c)
    if area == areaLargestMax:
        cv2.drawContours(img_input, contours, i, (255, 0, 0), 2)
print areaLargestMax       
plt.imshow(img_input)
# Out:
# 7121.5

# %%
areaArray = []
count = 1
for i, c in enumerate(contours):
    area = cv2.contourArea(c)
    areaArray.append(area)
    areaLargest = np.argmax(areaArray)
    areaLargestMax = max(areaArray)
    areaLargestCnt = contours[areaLargest]
    x, y, w, h = cv2.boundingRect(areaLargestCnt)   
    if area == areaLargestMax:
        img2=cv2.drawContours(im, contours, i, (255, 0, 0), 2)
        img2=cv2.rectangle(im, (x, y), (x+w, y+h), (0,255,0), 2)
plt.imshow(im)
